# %% [markdown]
# # Ground-roll attenuation model with attention. 1D
# ## Attention branch as regression of noise mask parameters

# %% [markdown]
# Raw field seismograms contain noises of various nature. One type of noise is assosiated with ground-roll waves propagation. The model should suppress the ground-roll noise and keep desired signal unchanged.

# %% [markdown]
# * [Dataset](#Dataset)
# * [Model architecture](#Model-architecture)
# * [Training](#Training)
# * [Inference](#Inference)
# * [Runnig time](#Running-time)
# * [Model evaluation](#Model-evaluation)
# * [Criticism](#Criticism)
# * [Conclusion](#Conclusion)
# * [Suggestions for improvements](#Suggestions-for-improvements)

# %% [markdown]
# ## Dataset
#
# We exploit the Dataset 1 from a list of dataset on ground-roll attenuation. Description of the Dataset 1 is available [here](https://github.com/gazprom-neft/SeismicPro/blob/master/datasets/ground-roll_attenuation.ipynb). 10 first seismograms of the train part we keep for model training, the rest ones for testing.
#
# Required imports:

# %%
import sys
sys.path.append('../..')

import warnings
warnings.filterwarnings('ignore')
from tensorflow import logging
logging.set_verbosity(logging.ERROR)

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import shutil
import pprint

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt


from seismicpro.batchflow import Pipeline, V, B, L, I, W

from seismicpro.batchflow.batchflow.models.tf import UNet, VGG7, VGG16
from seismicpro.batchflow.batchflow.models.tf.nn.activations import h_sigmoid

from seismicpro.src import (SeismicDataset, FieldIndex, TraceIndex, statistics_plot,
                            seismic_plot, spectrum_plot, merge_segy_files)
from seismicpro.models import attention_loss_gauss


from Ground_Roll.src.unet_att2_params import UnetAttParams

# %env CUDA_VISIBLE_DEVICES=7
# Out:
# env: CUDA_VISIBLE_DEVICES=7

# %% [markdown]
# Index dataset

# %%
path_raw = '/notebooks/data/noise_dataset_1/DN02A_LIFT_AMPSCAL.sgy'
path_lift = '/notebooks/data/noise_dataset_1/DN02B_SHOTS_LIFT1.sgy'

index = (FieldIndex(name='raw', extra_headers=['offset'], path=path_raw)
         .merge(FieldIndex(name='lift', path=path_lift)))
index.head()
# Out:
#             TraceNumber offset TRACE_SEQUENCE_FILE  \
#                                                raw
# FieldRecord
# 111906             1656     35                   1
# 111906             1657     36                   2
# 111906             1655     78                   3
# 111906             1658     79                   4
# 111906             1654    127                   5
#
#                                                        file_id  \
#                                                            raw
# FieldRecord
# 111906       /notebooks/data/noise_dataset_1/DN02A_LIFT_AMP...
# 111906       /notebooks/data/noise_dataset_1/DN02A_LIFT_AMP...
# 111906       /notebooks/data/noise_dataset_1/DN02A_LIFT_AMP...
# 111906       /notebooks/data/noise_dataset_1/DN02A_LIFT_AMP...
# 111906       /notebooks/data/noise_dataset_1/DN02A_LIFT_AMP...
#
#             TRACE_SEQUENCE_FILE  \
#                            lift
# FieldRecord
# 111906                        1
# 111906                        2
# 111906                        3
# 111906                        4
# 111906                        5
#
#                                                        file_id
#                                                           lift
# FieldRecord
# 111906       /notebooks/data/noise_dataset_1/DN02B_SHOTS_LI...
# 111906       /notebooks/data/noise_dataset_1/DN02B_SHOTS_LI...
# 111906       /notebooks/data/noise_dataset_1/DN02B_SHOTS_LI...
# 111906       /notebooks/data/noise_dataset_1/DN02B_SHOTS_LI...
# 111906       /notebooks/data/noise_dataset_1/DN02B_SHOTS_LI...

# %% [markdown]
# Reserve 10 field records for model training:

# %%
tindex = TraceIndex(index.create_subset(index.indices[:10]))
train_set = SeismicDataset(tindex)

# %% [markdown]
# ## Model architecture
#
# Model consists of 2 branches, the first one is U-Net that performs noise modelling, the second one generates attention mask.
# Attention branch is a VGG7 with regression head and it learns the beginning and the end of a ground roll area.
# Noise mask is calculated as follows:
# ```
# x = range(seismogram_length)
# mask = sigmoid(x - ground_roll_beginning) * sigmoid(ground_roll_end - x)
# ```
#
# In the head of the entire model the output from U-Net (ground roll model) and raw seismogram are combined using the mask:
# `model_out = raw - unet_out * mask`. Thus the raw seismogram is changed only where grownd roll was detected by attention branch
#
# Loss is calculated using both model output and mask:
# `abs(target - model_output) + balance * mean(mask)`. Both difference between model output and target and mask size are minimized. `balance` is hyper-parameter.

# %% [markdown]
# Define the model config and loss function:

# %%
model_config = {
    'initial_block/inputs': 'trace_raw',
    'inputs': dict(trace_raw={'shape': (3000, 1)},
                   lift={'name': 'targets', 'shape': (3000, 1)}),
    'loss': (attention_loss_gauss, {'balance': 0.05}),
    'optimizer': ('Adam', {'learning_rate': 0.0001}),
    'common/data_format': 'channels_last',
    'common/main_base_class': UNet,
    'common/att_base_class': VGG16,
    'body': {
        'main': {
            'encoder/blocks': dict(layout='ca ca',
                                   filters=[16, 32, 64, 128, 256],
                                   kernel_size=[7, 5, 5, 5, 5],
                                   activation=tf.nn.elu),
            'encoder/downsample': dict(layout='pd',
                                       pool_size=2,
                                       pool_strides=2,
                                       dropout_rate=0.05),
            'embedding': dict(layout='ca ca', kernel_size=5, filters=512),
            'decoder/blocks': dict(layout='ca ca',
                                   filters=[16, 32, 64, 128, 256][::-1],
                                   kernel_size=[7, 5, 5, 5, 5][::-1],
                                   activation=tf.nn.elu),
            'decoder/upsample': dict(layout='tad',
                                     kernel_size=[7, 5, 5, 5, 5][::-1],
                                     strides=2,
                                     dropout_rate=0.05,
                                     activation=tf.nn.elu, ),
        },
        'att': {},
    },
    'head': {
        'main': dict(layout='c', filters=1, units=1),
        'att': dict(layout='fa', units=2, activation=h_sigmoid),
        'mode': 'noise',
    },

    'train_steps': {'step_main': {'scope': 'main_branch'},
                 'step_attention': {'scope': 'attention_branch'}}
}

# %% [markdown]
# ## Training

# %% [markdown]
# Training pipeline actions:
# * loading a batch of raw and target traces
# * model weights update
#
# Optimizer configuration:
# * optimizer: Adam
# * learning_rate = 0.0001
#
# Loss balance: 0.05
#
# Training scheme:
# * ```batch_size``` = 64
# * ```n_epochs``` = 2.

# %% [markdown]
# Define a train pipeline:

# %%
def exp_stack(x):
    return np.expand_dims(np.vstack(x), -1)

def make_data(batch, **kwagrs):
    return {'trace_raw': exp_stack(batch.raw), 'lift': exp_stack(batch.lift)}

train_pipeline = (Pipeline()
                  .init_model('static', UnetAttParams, name='unet', config=model_config)
                  .init_variable('loss', default=list())
                  .load(components=('raw', 'lift'), fmt='segy', tslice=np.arange(3000))
                  .train_model('unet', make_data=make_data, fetches='loss_step_main', save_to=V('loss', 'a'))
                 )

# %% [markdown]
# Specify a dataset for model training:

# %%
train_pipeline = train_pipeline << train_set

# %% [markdown]
# Run model training for 3 epochs with batch size of 64:

# %%
batch_size = 64

train_pipeline = train_pipeline.run(batch_size=batch_size, n_epochs=2, drop_last=True,
                                    shuffle=True, bar=True, bar_desc=W(V('loss')[-1].format('Current loss is: {:7.7}')))
# Out:
# Current loss is: 0.01371083: 100%|██████████| 1080/1080 [09:36<00:00,  1.87it/s]

# %% [markdown]
# Plot loss function decay:

# %%
loss = np.array(train_pipeline.get_variable('loss'))
plt.plot(loss)
plt.ylim(0, 0.2)
plt.show()

# %% [markdown]
# Calculate average loss during last 100 iterations

# %%
from scipy import stats
stats.describe(loss[-100:])
# Out:
# DescribeResult(nobs=100, minmax=(0.011573294, 0.020517156), mean=0.015509144, variance=4.1901953e-06, skewness=0.21937723457813263, kurtosis=-0.6679534373865037)

# %% [markdown]
# ## Test

# %% [markdown]
# Here we define a simple test procedure:
# `i` is a test field number
# * Load the model from training pipeline
# * load data from i-th field
# * predict outputs for each trace in the field
# * save model output and mask
# * plot raw seismogram, mask, model output and differences between model output and raw and model output and lift

# %%
fetches=['out_lift', 'mask', 'out_main']

test_pipeline = (Pipeline()
                 .import_model('unet', train_pipeline)
                 .init_variable('res', default=list())
                 .init_variable('raw', default=list())
                 .init_variable('lift', default=list())
                 .load(components=('raw', 'lift'), fmt='segy', tslice=np.arange(3000))
                 .update_variable('raw', B('raw'), mode='a')
                 .update_variable('lift', B('lift'), mode='a')
                 .predict_model('unet', make_data=make_data, fetches=fetches, save_to=V('res', 'a')))


def check_res(i, test_pipeline, cv=0.1):  
    test_set = SeismicDataset(TraceIndex(index.create_subset(index.indices[i: i+1])))
    test_pipeline = test_pipeline << test_set
    test_pipeline = test_pipeline.run(batch_size=500, n_epochs=1, drop_last=False,
                                  shuffle=False, bar=True)
    raw = np.vstack([np.vstack(x) for x in test_pipeline.get_variable('raw')])
    lift = np.vstack([np.vstack(x) for x in test_pipeline.get_variable('lift')])
    out = np.squeeze(np.vstack([x[0] for x in test_pipeline.get_variable('res')]))
    att = np.squeeze(np.vstack([x[1] for x in test_pipeline.get_variable('res')]))
    noise = np.squeeze(np.vstack([x[2] for x in test_pipeline.get_variable('res')]))
    seismic_plot([raw, att, noise, out, out - raw, out -lift],
             figsize=(19, 7), names=['RAW', 'NOISE MASK', 'NOISE MODEL', 'OUTPUT', 'OUTPUT - RAW', 'out-lift'],
             cmap='gray', vmin=-cv, vmax=cv, title='Field {}'.format(index.indices[i]))
    
    return raw, att, lift, out, noise
# Out:
# WARNING:root:update_variable() is deprecated. Use pipeline.update(V(name), value) instead.
# WARNING:root:update_variable() is deprecated. Use pipeline.update(V(name), value) instead.

# %% [markdown]
# Run test pipeline:

# %%
i = 20
raw, att, lift, out, noise = check_res(i, test_pipeline)
# Out:
# 100%|██████████| 7/7 [00:13<00:00,  1.92s/it]

# %% [markdown]
# We can see that the mask is not detected around first-break area, which is good, but the mask quality still needs improvements
#
# Let's plot single traces.

# %%
def plot_trace(tr_no, att, raw, out, ax):
    ax.plot(att[tr_no], label='mask', alpha=0.7)
    ax.plot(raw[tr_no], label='raw', alpha=0.7)
    ax.plot(out[tr_no], label='out', alpha=0.7)
    ax.legend()
    ax.set_title('trace {}'.format(tr_no));
    ax.set_ylim(-1.5, 1.5);
    
def plot_traces(tr_nums, att, raw, out):
    fig, axs = plt.subplots(1, len(tr_nums), figsize=(20, 5))
    for i, tr_no in enumerate(tr_nums):
        plot_trace(tr_no, att, raw, out, axs[i])

# %% [markdown]
# In previous version of this notebook with shallower models the mask was underestimated for ttrace 500, and too large for its neigbour 501.
# Deeper model shows better mask quality

# %%
plot_traces((500, 501), att, raw, out)

# %% [markdown]
# Mask detection is stil not very good for very small and very large offsets

# %%
plot_traces((925, 926), att, raw, out)

# %% [markdown]
# But we can see that despite the drawbacks of mask detection noise filtering branch does not modify the signal outside true ground roll area very much

# %%
plot_traces((50, 100), att, raw, out)

# %% [markdown]
# More research on model architecture is needed

# %% [markdown]
# Below are enlarged crops from field 111927 and output for few other fields

# %%
seismic_plot([raw, att, out, lift], xlim=(0, 500), ylim=(0, 2000),
             figsize=(19, 7), names=['raw','MASK', 'out', 'lift'],
             cmap='gray', vmin=-1, vmax=1)

# %%
seismic_plot([raw - lift, noise, raw - lift - noise], #xlim=(850, 1000), ylim=(2000, 3000),
             figsize=(19, 7), names=['raw - lift','Noise', 'diff'],
             cmap='gray', vmin=-0.1, vmax=0.1)

# %%
seismic_plot([raw, att], xlim=(850, 1000), ylim=(2000, 3000),
             figsize=(19, 7), names=['raw','Noise Raw', 'NOISE MASK'],
             cmap='gray', vmin=-1, vmax=1)

# %%
seismic_plot([raw, att], xlim=(500, 600), ylim=(1500, 2500),
             figsize=(19, 7), names=['raw','Noise Raw', 'NOISE MASK'],
             cmap='gray', vmin=-1, vmax=1)

# %%
i = 21
check_res(i, test_pipeline);
# Out:
# 100%|██████████| 7/7 [00:10<00:00,  1.49s/it]

# %%
i = 30
check_res(i, test_pipeline);
# Out:
# 100%|██████████| 7/7 [00:08<00:00,  1.19s/it]

# %%
i = 47
ree = check_res(i, test_pipeline);
# Out:
# 100%|██████████| 7/7 [00:08<00:00,  1.18s/it]

# %% [markdown]
# ## Inference

# %%
boom!

# %%
def make_data_inference(batch, **kwagrs):
    return {'trace_raw': exp_stack(batch.raw)}

tmp_dump_path = 'tmp'
if os.path.exists(tmp_dump_path):
    shutil.rmtree(tmp_dump_path)
os.makedirs(tmp_dump_path)

inference_pipeline = (SeismicDataset(TraceIndex(index)).p
                      .import_model('unet', train_pipeline)
                      .load(components='raw', fmt='segy', tslice=np.arange(3000))
                      .predict_model('unet', make_data=make_data_inference, fetches=["out_lift"], save_to=B('raw'))
                      .dump(path=L(lambda x: os.path.join(tmp_dump_path, str(x) + '.sgy'))(I()), src='raw', fmt='segy', split=False)
                     )
inference_pipeline.run(1000, n_epochs=1, drop_last=False, shuffle=False, bar=True)

output_path=os.path.join('1_model_inference', 'noise_dataset_1_unet_att_params_1.sgy')
merge_segy_files(output_path=output_path, extra_headers='all', path=os.path.join(tmp_dump_path, '*.sgy'))

if os.path.exists(tmp_dump_path):
    shutil.rmtree(tmp_dump_path) 

with open(output_path + '.cfg', 'w') as inpf:
    inpf.write("Fields from train set: {}\n".format(FieldIndex(tindex).indices))
    inpf.write("\nModel config\n")
    inpf.write(pprint.pformat(model_config, compact=True))
